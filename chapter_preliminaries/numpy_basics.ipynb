# %% [markdown]
# <a href="https://colab.research.google.com/github/verysweatydog/d2l.ai/blob/main/chapter_preliminaries/numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

s = pd.Series(["dog",2,3,4,5])
s
# Out:
# 0    dog
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: object

# %%
x = pd.date_range("20250511", periods = 7)

dates = pd.DataFrame(np.random.randn(7,3), index = x, columns = list("PIS"))
dates
# Out:
#                    P         I         S
# 2025-05-11 -0.718354  0.990590 -0.432583
# 2025-05-12  0.679894 -0.370108  0.698161
# 2025-05-13  0.962807 -0.121754  0.958715
# 2025-05-14 -0.738186  0.312410 -0.505439
# 2025-05-15 -1.427060  1.582116  1.877878
# 2025-05-16  0.138271  0.824519  0.444925
# 2025-05-17 -0.012797 -1.227500 -1.624810

# %%
df2 = pd.DataFrame(
     {
        "A": 1.0,
        "B": pd.date_range("20130102", periods = 4),
        "C": pd.Series(1, index=list(range(4)), dtype="int32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
     }
 )
print(df2)

print(df2.head(2))

print(df2.tail(3))

print(df2.index)
print(df2.columns)

print(df2.to_numpy())
# Out:
#      A          B  C  D      E    F
# 0  1.0 2013-01-02  1  3   test  foo
# 1  1.0 2013-01-03  1  3  train  foo
# 2  1.0 2013-01-04  1  3   test  foo
# 3  1.0 2013-01-05  1  3  train  foo
#      A          B  C  D      E    F
# 0  1.0 2013-01-02  1  3   test  foo
# 1  1.0 2013-01-03  1  3  train  foo
#      A          B  C  D      E    F
# 1  1.0 2013-01-03  1  3  train  foo
# 2  1.0 2013-01-04  1  3   test  foo
# 3  1.0 2013-01-05  1  3  train  foo
# Index([0, 1, 2, 3], dtype='int64')
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')
# [[1.0 Timestamp('2013-01-02 00:00:00') 1 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-03 00:00:00') 1 3 'train' 'foo']
#  [1.0 Timestamp('2013-01-04 00:00:00') 1 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-05 00:00:00') 1 3 'train' 'foo']]

# %%
print(dates)
print(dates.describe())

dates.T

dates.sort_index(axis=1, ascending=False)

dates.sort_values(by = "S")
# Out:
#                    P         I         S
# 2025-05-11 -0.718354  0.990590 -0.432583
# 2025-05-12  0.679894 -0.370108  0.698161
# 2025-05-13  0.962807 -0.121754  0.958715
# 2025-05-14 -0.738186  0.312410 -0.505439
# 2025-05-15 -1.427060  1.582116  1.877878
# 2025-05-16  0.138271  0.824519  0.444925
# 2025-05-17 -0.012797 -1.227500 -1.624810
#               P         I         S
# count  7.000000  7.000000  7.000000
# mean  -0.159346  0.284325  0.202407
# std    0.849338  0.944675  1.149404
# min   -1.427060 -1.227500 -1.624810
# 25%   -0.728270 -0.245931 -0.469011
# 50%   -0.012797  0.312410  0.444925
# 75%    0.409082  0.907555  0.828438
# max    0.962807  1.582116  1.877878
#                    P         I         S
# 2025-05-17 -0.012797 -1.227500 -1.624810
# 2025-05-14 -0.738186  0.312410 -0.505439
# 2025-05-11 -0.718354  0.990590 -0.432583
# 2025-05-16  0.138271  0.824519  0.444925
# 2025-05-12  0.679894 -0.370108  0.698161
# 2025-05-13  0.962807 -0.121754  0.958715
# ...

# %% [markdown]
# Next section to be completed: Selection
# https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
